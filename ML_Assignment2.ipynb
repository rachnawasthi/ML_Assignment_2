# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.5 MB/s  0:00:00 eta 0:00:01
# ...

# %%
pip install xgboost
# Out:
# ...
#   Using cached xgboost-3.4.1-py3-none-macosx_12_0_arm64.whl.metadata (2.0 kB)
# ...
# Using cached xgboost-3.4.1-py3-none-macosx_12_0_arm64.whl (2.4 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.4/20.4 MB 2.8 MB/s  0:00:07m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [xgboost]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python train_models.py
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:200: UserWarning: [12:00:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:794:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#                  Model  Accuracy       AUC  ...    Recall        F1       MCC
# 0       logistic_model  0.973684  0.997380  ...  0.985915  0.979021  0.943898
# 1  decision_tree_model  0.947368  0.943990  ...  0.957746  0.957746  0.887979
# 2            knn_model  0.947368  0.981985  ...  0.957746  0.957746  0.887979
# 3    naive_bayes_model  0.973684  0.998362  ...  1.000000  0.979310  0.944733
# 4  random_forest_model  0.964912  0.995251  ...  0.985915  0.972222  0.925285
# 5        xgboost_model  0.964912  0.993449  ...  0.985915  0.972222  0.925285
#
# [6 rows x 7 columns]
